# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodzeymer/Imersao_Python/blob/main/Imers%C3%A3o_Python_Aula_02_Parte_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá, estamos agora saindo do ambiente de planilhas do Excel, Google Sheets ou do Libreoffice Calc (que travou depois que coloquei o segundo gráfico e tentei fazer qualquer coisa à mais). Mostrando que apesar de serem aplicativos poderosos, existe uma limitação, de quantos dados, quantas fórmulas cada aplicativo pode realizar ao mesmo tempo.
#
# Agora estamos entrando no ambiente da programação, e com o Python e suas bibliotecas, o limite é expandido, podemos operar com milhões, até bilhôes de dados, usar fórmulas mais complexas do que as ofertadas anteriormente e lecaionar isso com bancos de dados diversos e outras fontes de dados.
#
# Além de gerar gráficos mais avançados, bonitos e coloridos, não é porque vamos usar códigos que a parte gráfica fica reduzida.
#
# Primeiramente primeiro, temos que importar esses dados, os quais estávamos trabalhando no ambiente anterior. Primeiro salvamos a planilha no computador da gente para depois carregarmos o arquivo aqui no notebook, pois o notebook não irá manter os arquivos salvos depois que fecharmos ele, para voltar a trabalhar teremos que carregar novamente os arquivos, e sempre que fizermos alterações nele é preciso que ele seja salvo fazendo o seu download no nosso computador pessoal.

# %%
import pandas as pd

caminhoArquivo = "/content/Imersão Python - Tabela de ações.xlsx"

df_principal = pd.read_excel(caminhoArquivo, sheet_name="Principal")

df_total_acoes = pd.read_excel(caminhoArquivo, sheet_name="Total_de_acoes")

df_ticker = pd.read_excel(caminhoArquivo, sheet_name="Ticker")

df_principal.head()
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# 0          2.26         15.97      9.18      9.56  319,16 M
# 1        -12.11         50.56      6.66      6.86   32,65 M
# 2          7.64         77.55     40.81     42.34  436,69 M
# 3         -4.89         18.85     51.89     53.17  162,55 M
# 4         -3.66         20.70     36.37     37.32   73,42 M

# %% [markdown]
# Podemos ainda, para facilitar as operações, atribuir cada coluna das tabelas a uma variável diferente.

# %%
ativo_principal = df_principal["Ativo"]

ativo_principal.head()
# Out:
# 0    USIM5
# 1    CMIN3
# 2    PETR3
# 3    SUZB3
# 4    CPFE3
# Name: Ativo, dtype: object
